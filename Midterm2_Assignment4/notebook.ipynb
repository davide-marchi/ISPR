# %% [markdown]
# # Davide Marchi
# ## Assignment 4

# %% [markdown]
# ### Imported modules
# The realizations of the Bayesian Network starts by importing two needed modules: 'random' and 'itertools'
# The first one will be needed to randomly generate the samples during ancestral sampling with the function 'random()' while 'itertools' will be usuful to create a list of all the possible permutations of the states of the parents of a node with 'product()'

# %%
# Import librarires
import random
import itertools

# %% [markdown]
# ### Bayesian Network class
# I have then implemented the 'BayesianNetwork' class, which represent a Directed Acyclic Graph whose nodes are random variables and the edges describe the conditional independence relationships.
# To implement so i opted to represet the graph as a dictionary, whe...

# %%
# Define the Bayesian Network class
class BayesianNetwork:
    def __init__(self):
        self.nodes = {}
    
    # Add a node to the network after checking for validity
    def add_node(self, name, states, cpt, parents=[]):

        # Check if the node already exists in the network
        if name in self.nodes:
            print(f"Node '{name}' already exists in the network.")
            return
        
        # Check if the node has at least one state
        if len(states) == 0:
            print(f"Node '{name}' must have at least one state.")
            return
        
        # Check if all parent nodes exist in the network
        for parent in parents:
            if parent not in self.nodes:
                print(f"Parent node '{parent}' does not exist in the network.")
                return

        # Check if the CPT is valid
        for parent_combination in itertools.product(*[self.nodes[parent]['states'] for parent in parents]):
            if parent_combination not in cpt or len(cpt[parent_combination]) != len(states) or sum(cpt[parent_combination]) != 1:
                print(f"Invalid CPT for node '{name}'.")
                return

        self.nodes[name] = {'states': states, 'parents': parents, 'cpt': cpt}
    
    # Calculate the probability of a state of a node given its parents' states
    def probability(self, node, parent_states, state):
        states = self.nodes[node]['states']
        return self.nodes[node]['cpt'][parent_states][states.index(state)]
    
    # Sample a state for a node given its parents' states
    def sample(self, node, parent_states):
        print('sampling node:', node, 'with parent states:', parent_states, '...')
        p = random.random()
        cumulative_prob = 0
        states = self.nodes[node]['states']
        for state in states:
            probability = self.probability(node, parent_states, state)
            cumulative_prob += probability
            if p <= cumulative_prob:
                return state, probability
    
    # Sample states for all nodes
    def sample_states(self):
        sampled_states = {}
        joint_probability = 1
        for node in self.nodes:
            parents = self.nodes[node]['parents']
            parent_states = tuple(sampled_states[parent] for parent in parents)
            sampled_states[node], probaility = self.sample(node, parent_states)
            joint_probability *= probaility
        return sampled_states, joint_probability

# %% [markdown]
# ### Network example
# To show the functionality of the presented implementation here is presented an example of istantiation of an object of the 'BayesianNetwork' class.

# %%
# Define conditional probability tables (CPTs)
study_cpt = {
    (): [0.2, 0.6, 0.2]  # P(Study Time)
}
sleep_cpt = {
    (): [0.3, 0.5, 0.2]  # P(Sleep Quality)
}
stress_cpt = {
    (): [0.3, 0.5, 0.2]  # P(Stress Level)
}
exam_cpt = {
    ('Low', 'Low', 'Low'): [0.8, 0.15, 0.05],     # P(Exam Difficulty | Study, Sleep, Stress)
    ('Low', 'Low', 'Medium'): [0.7, 0.2, 0.1],
    ('Low', 'Low', 'High'): [0.6, 0.3, 0.1],
    ('Low', 'Medium', 'Low'): [0.7, 0.2, 0.1],
    ('Low', 'Medium', 'Medium'): [0.6, 0.3, 0.1],
    ('Low', 'Medium', 'High'): [0.5, 0.35, 0.15],
    ('Low', 'High', 'Low'): [0.6, 0.3, 0.1],
    ('Low', 'High', 'Medium'): [0.5, 0.35, 0.15],
    ('Low', 'High', 'High'): [0.4, 0.4, 0.2],
    ('Medium', 'Low', 'Low'): [0.7, 0.2, 0.1],
    ('Medium', 'Low', 'Medium'): [0.6, 0.3, 0.1],
    ('Medium', 'Low', 'High'): [0.5, 0.35, 0.15],
    ('Medium', 'Medium', 'Low'): [0.6, 0.3, 0.1],
    ('Medium', 'Medium', 'Medium'): [0.5, 0.35, 0.15],
    ('Medium', 'Medium', 'High'): [0.4, 0.4, 0.2],
    ('Medium', 'High', 'Low'): [0.5, 0.35, 0.15],
    ('Medium', 'High', 'Medium'): [0.4, 0.4, 0.2],
    ('Medium', 'High', 'High'): [0.3, 0.5, 0.2],
    ('High', 'Low', 'Low'): [0.6, 0.3, 0.1],
    ('High', 'Low', 'Medium'): [0.5, 0.35, 0.15],
    ('High', 'Low', 'High'): [0.4, 0.4, 0.2],
    ('High', 'Medium', 'Low'): [0.5, 0.35, 0.15],
    ('High', 'Medium', 'Medium'): [0.4, 0.4, 0.2],
    ('High', 'Medium', 'High'): [0.3, 0.5, 0.2],
    ('High', 'High', 'Low'): [0.4, 0.4, 0.2],
    ('High', 'High', 'Medium'): [0.3, 0.5, 0.2],
    ('High', 'High', 'High'): [0.2, 0.6, 0.2],
}
health_cpt = {
    ('Low',): [0.1, 0.6, 0.3],     # P(Health | Stress Level)
    ('Medium',): [0.3, 0.5, 0.2],
    ('High',): [0.5, 0.4, 0.1],
}
motivation_cpt = {
    ('Low', 'Low'): [0.1, 0.6, 0.3],    # P(Motivation | Stress Level, Sleep Quality)
    ('Low', 'Medium'): [0.2, 0.6, 0.2],
    ('Low', 'High'): [0.3, 0.5, 0.2],
    ('Medium', 'Low'): [0.2, 0.6, 0.2],
    ('Medium', 'Medium'): [0.3, 0.5, 0.2],
    ('Medium', 'High'): [0.4, 0.4, 0.2],
    ('High', 'Low'): [0.3, 0.5, 0.2],
    ('High', 'Medium'): [0.4, 0.4, 0.2],
    ('High', 'High'): [0.5, 0.3, 0.2],
}
distraction_cpt = {
    (): [0.7, 0.2, 0.1]    # P(External Distractions)
}
caffeine_cpt = {
    (): [0.3, 0.5, 0.2]    # P(Caffeine Intake)
}
nutrition_cpt = {
    (): [0.2, 0.6, 0.2]    # P(Nutrition)
}
social_cpt = {
    (): [0.3, 0.5, 0.2]    # P(Social Life)
}

# Initialize Bayesian Network
bn = BayesianNetwork()

# Add nodes to the network with their CPTs
bn.add_node('Study Time', ['Low', 'Medium', 'High'], cpt=study_cpt)
bn.add_node('Sleep Quality', ['Low', 'Medium', 'High'], cpt=sleep_cpt)
bn.add_node('Stress Level', ['Low', 'Medium', 'High'], cpt=stress_cpt)
bn.add_node('Exam Difficulty', ['Easy', 'Medium', 'Hard'], cpt=exam_cpt, parents=['Study Time', 'Sleep Quality', 'Stress Level'])
bn.add_node('Health', ['Good', 'Okay', 'Poor'], cpt=health_cpt, parents=['Stress Level'])
bn.add_node('Motivation', ['Low', 'Medium', 'High'], cpt=motivation_cpt, parents=['Stress Level', 'Sleep Quality'])
bn.add_node('External Distractions', ['Low', 'Medium', 'High'], cpt=distraction_cpt)
bn.add_node('Caffeine Intake', ['Low', 'Medium', 'High'], cpt=caffeine_cpt)
bn.add_node('Nutrition', ['Poor', 'Average', 'Good'], cpt=nutrition_cpt)
bn.add_node('Social Life', ['Low', 'Medium', 'High'], cpt=social_cpt)

# %% [markdown]
# ### Ancestral Sampling
# To assess the ability to perform the Ancestral Sampling i went for multiple calls to the 'sample_states()' function.
# A certain number of iterations will give us enough data to try to make assumptions regarding which states are most likely to be reached ny the nodes.

# %%
# Cycle to perform multiple episodes of sampling
for i in range(100):

    # Sample states for all nodes
    sampled_states, joint_probability = bn.sample_states()

    # Print sampled states
    for node, state in sampled_states.items():
        print(f"{node}: {state}")

    # Print joint probability
    print(f"Joint Probability: {joint_probability}")
# Out:
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Medium', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Medium
# Stress Level: Low
# Exam Difficulty: Easy
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: High
# Joint Probability: 0.00013607999999999998
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'Low', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: Low
# Stress Level: Low
# Exam Difficulty: Easy
# Health: Poor
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.00016329599999999998
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Medium', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Medium
# Stress Level: High
# Exam Difficulty: Easy
# Health: Good
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: High
# Joint Probability: 5.040000000000001e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'High', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: High
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Good
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: High
# Joint Probability: 0.00012096
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'Low', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: Low
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Okay
# Motivation: Low
# External Distractions: Medium
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 6.3e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Poor
# Motivation: High
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.00031499999999999996
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: High
# Exam Difficulty: Easy
# Health: Poor
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Low
# Joint Probability: 6.0480000000000004e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Low', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Low
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Good
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: High
# Joint Probability: 0.00013607999999999998
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'Low', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: Low
# Stress Level: Low
# Exam Difficulty: Easy
# Health: Okay
# Motivation: High
# External Distractions: Low
# Caffeine Intake: High
# Nutrition: Poor
# Social Life: High
# Joint Probability: 1.4515200000000001e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'Low', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: Low
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Good
# Motivation: High
# External Distractions: Medium
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Low
# Joint Probability: 2.2679999999999996e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Okay
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: High
# Nutrition: Poor
# Social Life: Medium
# Joint Probability: 0.00011025
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Low', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Low
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Poor
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: High
# Joint Probability: 0.00027215999999999997
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Okay
# Motivation: High
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.00031499999999999996
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Hard
# Health: Poor
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.00014174999999999998
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Low', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Low
# Stress Level: Medium
# Exam Difficulty: Hard
# Health: Good
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 8.504999999999998e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: High
# Exam Difficulty: Easy
# Health: Good
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.0003024
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Low', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Low
# Stress Level: Low
# Exam Difficulty: Medium
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Poor
# Social Life: Medium
# Joint Probability: 0.00013607999999999998
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'High', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: High
# Stress Level: Low
# Exam Difficulty: Medium
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Good
# Social Life: Low
# Joint Probability: 2.2679999999999996e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Medium', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Medium
# Stress Level: Low
# Exam Difficulty: Hard
# Health: Poor
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Low
# Nutrition: Good
# Social Life: High
# Joint Probability: 6.8039999999999996e-06
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'High', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: High
# Stress Level: Medium
# Exam Difficulty: Hard
# Health: Good
# Motivation: Low
# External Distractions: Medium
# Caffeine Intake: Medium
# Nutrition: Poor
# Social Life: Medium
# Joint Probability: 1.4400000000000001e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Low', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Low
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Good
# Motivation: Low
# External Distractions: Medium
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 5.832e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Poor
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: High
# Nutrition: Average
# Social Life: Low
# Joint Probability: 3.0240000000000005e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Low', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Low
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Good
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.00011906999999999996
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'Medium', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: Medium
# Stress Level: Low
# Exam Difficulty: Easy
# Health: Okay
# Motivation: High
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Good
# Social Life: High
# Joint Probability: 3.5279999999999994e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Okay
# Motivation: Medium
# External Distractions: Medium
# Caffeine Intake: Low
# Nutrition: Poor
# Social Life: Medium
# Joint Probability: 0.0001125
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Low', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Low
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Good
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.0003061799999999999
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Low', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Low
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Okay
# Motivation: High
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.0002835
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'High', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: High
# Stress Level: High
# Exam Difficulty: Easy
# Health: Poor
# Motivation: High
# External Distractions: Low
# Caffeine Intake: High
# Nutrition: Poor
# Social Life: Medium
# Joint Probability: 2.0160000000000003e-06
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Low', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Low
# Stress Level: High
# Exam Difficulty: Medium
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Low
# Nutrition: Poor
# Social Life: Low
# Joint Probability: 3.175199999999999e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Medium', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Medium
# Stress Level: High
# Exam Difficulty: Medium
# Health: Good
# Motivation: High
# External Distractions: Low
# Caffeine Intake: High
# Nutrition: Poor
# Social Life: Medium
# Joint Probability: 1.4000000000000001e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'High', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: High
# Stress Level: Medium
# Exam Difficulty: Hard
# Health: Okay
# Motivation: Low
# External Distractions: High
# Caffeine Intake: High
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 1.4400000000000001e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'High', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: High
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: High
# Nutrition: Good
# Social Life: Medium
# Joint Probability: 6.720000000000001e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: High
# Exam Difficulty: Medium
# Health: Good
# Motivation: Low
# External Distractions: Medium
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: Low
# Joint Probability: 5.184e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Hard
# Health: Good
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Good
# Social Life: High
# Joint Probability: 1.0500000000000003e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Low', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Low
# Stress Level: High
# Exam Difficulty: Hard
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.00011339999999999999
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: High
# Joint Probability: 0.0007875
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'High', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: High
# Stress Level: Low
# Exam Difficulty: Hard
# Health: Okay
# Motivation: Low
# External Distractions: Medium
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Low
# Joint Probability: 3.888000000000001e-06
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: Low
# Exam Difficulty: Medium
# Health: Poor
# Motivation: Medium
# External Distractions: High
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: High
# Joint Probability: 1.7496e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'Low', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: Low
# Stress Level: Low
# Exam Difficulty: Easy
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: High
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.00021772799999999999
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Low', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Low
# Stress Level: High
# Exam Difficulty: Medium
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Low
# Nutrition: Poor
# Social Life: Low
# Joint Probability: 1.2096000000000002e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Poor
# Motivation: High
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Low
# Joint Probability: 5.040000000000001e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: Low
# Exam Difficulty: Easy
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.0020411999999999995
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Medium', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Medium
# Stress Level: High
# Exam Difficulty: Easy
# Health: Poor
# Motivation: Low
# External Distractions: Medium
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Low
# Joint Probability: 4.320000000000002e-06
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'High', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: High
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Okay
# Motivation: High
# External Distractions: Low
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.0001512
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: Low
# Exam Difficulty: Easy
# Health: Good
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: High
# Nutrition: Good
# Social Life: Medium
# Joint Probability: 4.5360000000000006e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Low', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Low
# Stress Level: Low
# Exam Difficulty: Easy
# Health: Okay
# Motivation: High
# External Distractions: Medium
# Caffeine Intake: Medium
# Nutrition: Poor
# Social Life: High
# Joint Probability: 2.7215999999999998e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Hard
# Health: Good
# Motivation: Medium
# External Distractions: Medium
# Caffeine Intake: High
# Nutrition: Average
# Social Life: Low
# Joint Probability: 2.43e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Okay
# Motivation: High
# External Distractions: High
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 2.25e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: High
# Exam Difficulty: Easy
# Health: Good
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Poor
# Social Life: Medium
# Joint Probability: 0.00016800000000000002
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'High', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: High
# Stress Level: Low
# Exam Difficulty: Medium
# Health: Okay
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Poor
# Social Life: Low
# Joint Probability: 4.762799999999999e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'Low', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: Low
# Stress Level: Low
# Exam Difficulty: Hard
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: High
# Nutrition: Poor
# Social Life: Low
# Joint Probability: 2.7216e-06
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Low', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Low
# Stress Level: Medium
# Exam Difficulty: Hard
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: High
# Joint Probability: 6.803999999999999e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: Low
# Exam Difficulty: Easy
# Health: Poor
# Motivation: High
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Poor
# Social Life: Medium
# Joint Probability: 0.00011339999999999999
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Poor
# Motivation: Low
# External Distractions: Medium
# Caffeine Intake: Medium
# Nutrition: Good
# Social Life: High
# Joint Probability: 4.800000000000002e-06
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'Medium', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: Medium
# Stress Level: High
# Exam Difficulty: Hard
# Health: Good
# Motivation: High
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Low
# Joint Probability: 1.8900000000000002e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Hard
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.00026250000000000004
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: Low
# Exam Difficulty: Medium
# Health: Poor
# Motivation: High
# External Distractions: Low
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.00010205999999999997
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'Medium', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# ...
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Good
# Social Life: Medium
# Joint Probability: 0.0002835
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'High', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: High
# Stress Level: High
# Exam Difficulty: Medium
# Health: Good
# Motivation: Low
# External Distractions: High
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Low
# Joint Probability: 2.7000000000000002e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'High', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: High
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Okay
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: High
# Joint Probability: 8.400000000000002e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Medium', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Medium
# Stress Level: High
# Exam Difficulty: Medium
# Health: Okay
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Poor
# Social Life: Low
# Joint Probability: 3.360000000000001e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Low', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Low
# Stress Level: Low
# Exam Difficulty: Medium
# Health: Good
# Motivation: Medium
# External Distractions: Medium
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 1.1664e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'High', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: High
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Okay
# Motivation: High
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.000252
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Okay
# Motivation: Medium
# External Distractions: High
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 4.500000000000001e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Poor
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: High
# Joint Probability: 0.0001323
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'High', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: High
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Okay
# Motivation: Low
# External Distractions: Medium
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.000144
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: High
# Exam Difficulty: Easy
# Health: Good
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: High
# Nutrition: Poor
# Social Life: Low
# Joint Probability: 4.032e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Low', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Low
# Stress Level: Medium
# Exam Difficulty: Medium
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Low
# Joint Probability: 0.0005102999999999999
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Medium', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Medium
# Stress Level: Medium
# Exam Difficulty: Hard
# Health: Okay
# Motivation: Medium
# External Distractions: High
# Caffeine Intake: Medium
# Nutrition: Poor
# Social Life: Medium
# Joint Probability: 1.2500000000000004e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Medium', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Medium
# Stress Level: High
# Exam Difficulty: Easy
# Health: Okay
# Motivation: High
# External Distractions: Low
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: Medium
# Joint Probability: 0.00012096000000000001
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Low', 'High', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Low
# Sleep Quality: High
# Stress Level: Low
# Exam Difficulty: Easy
# Health: Good
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Good
# Social Life: High
# Joint Probability: 3.0240000000000006e-06
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Medium', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'Medium') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Medium
# Stress Level: High
# Exam Difficulty: Easy
# Health: Okay
# Motivation: High
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Poor
# Social Life: Medium
# Joint Probability: 1.6800000000000005e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'Low', 'Low') ...
# sampling node: Health with parent states: ('Low',) ...
# sampling node: Motivation with parent states: ('Low', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: Low
# Stress Level: Low
# Exam Difficulty: Easy
# Health: Poor
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: Medium
# Nutrition: Average
# Social Life: Low
# Joint Probability: 0.0004286519999999999
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('High', 'Low', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'Low') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: High
# Sleep Quality: Low
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Okay
# Motivation: Medium
# External Distractions: Low
# Caffeine Intake: High
# Nutrition: Poor
# Social Life: Medium
# Joint Probability: 6.3e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'High', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: High
# Stress Level: Medium
# Exam Difficulty: Easy
# Health: Okay
# Motivation: Low
# External Distractions: Low
# Caffeine Intake: High
# Nutrition: Poor
# Social Life: Low
# Joint Probability: 4.032e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'High', 'Medium') ...
# sampling node: Health with parent states: ('Medium',) ...
# sampling node: Motivation with parent states: ('Medium', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: High
# Stress Level: Medium
# Exam Difficulty: Hard
# Health: Okay
# Motivation: Medium
# External Distractions: Medium
# Caffeine Intake: Low
# Nutrition: Average
# Social Life: High
# Joint Probability: 1.728e-05
# sampling node: Study Time with parent states: () ...
# sampling node: Sleep Quality with parent states: () ...
# sampling node: Stress Level with parent states: () ...
# sampling node: Exam Difficulty with parent states: ('Medium', 'High', 'High') ...
# sampling node: Health with parent states: ('High',) ...
# sampling node: Motivation with parent states: ('High', 'High') ...
# sampling node: External Distractions with parent states: () ...
# sampling node: Caffeine Intake with parent states: () ...
# sampling node: Nutrition with parent states: () ...
# sampling node: Social Life with parent states: () ...
# Study Time: Medium
# Sleep Quality: High
# Stress Level: High
# Exam Difficulty: Easy
# Health: Poor
# Motivation: High
# External Distractions: Medium
# Caffeine Intake: High
# Nutrition: Good
# Social Life: Medium
# Joint Probability: 5.760000000000001e-07
